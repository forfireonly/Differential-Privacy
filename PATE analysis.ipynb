# %%
import torch
import numpy as np

# %%
num_teachers = 10 #working with 10 hospitals
num_examples = 10000 #size of dataset
num_labels = 10 #labels for our clasifier

# %%
preds = (np.random.rand(num_teachers, num_examples)*num_labels).astype(int).transpose(1,0)

# %%
new_labels = list()
for an_image in preds:
    label_counts = np.bincount(an_image, minlength=num_labels)
    epsilon = 0.1
    beta = 1 / epsilon
    for i in range(len(label_counts)):
        label_counts[i] += np.random.laplace(0, beta, 1)
        
    new_label = np.argmax(label_counts)
    
    new_labels.append(new_label)

# %%
len(new_labels)
# Out:
# 10000

# %%
print(new_labels)
# Out:
# [0, 9, 3, 7, 0, 3, 3, 2, 1, 0, 7, 0, 6, 5, 9, 8, 1, 2, 7, 6, 3, 4, 2, 2, 0, 2, 9, 4, 0, 4, 7, 1, 8, 7, 0, 6, 7, 6, 0, 2, 8, 8, 3, 3, 0, 4, 2, 8, 6, 7, 7, 2, 9, 0, 1, 9, 9, 6, 4, 7, 1, 8, 0, 3, 5, 5, 8, 1, 3, 8, 2, 5, 9, 9, 8, 1, 8, 8, 5, 8, 6, 8, 7, 7, 9, 7, 6, 5, 6, 5, 1, 5, 0, 9, 1, 6, 6, 3, 4, 1, 3, 9, 8, 8, 2, 5, 9, 5, 8, 0, 2, 1, 6, 2, 0, 5, 0, 1, 4, 4, 1, 9, 1, 8, 4, 0, 3, 0, 8, 1, 2, 4, 1, 7, 5, 5, 6, 6, 4, 3, 9, 4, 4, 5, 8, 8, 7, 4, 2, 3, 7, 0, 5, 0, 2, 5, 5, 3, 2, 3, 1, 6, 5, 9, 7, 9, 8, 8, 4, 3, 0, 8, 3, 4, 6, 0, 1, 6, 5, 0, 4, 7, 6, 4, 2, 0, 0, 3, 9, 2, 3, 5, 8, 7, 9, 7, 5, 5, 7, 3, 5, 5, 8, 9, 4, 4, 2, 1, 3, 2, 5, 7, 7, 3, 5, 0, 0, 8, 7, 8, 5, 4, 1, 7, 2, 3, 1, 6, 5, 3, 0, 7, 1, 0, 9, 0, 2, 5, 4, 7, 2, 9, 4, 4, 7, 0, 8, 5, 8, 3, 1, 4, 4, 1, 0, 9, 1, 0, 0, 5, 5, 7, 1, 7, 0, 5, 1, 6, 1, 7, 7, 5, 3, 3, 8, 0, 1, 2, 9, 3, 4, 0, 1, 9, 0, 1, 0, 2, 7, 3, 7, 8, 5, 2, 0, 4, 9, 8, 3, 9, 7, 2, 7, 1, 9, 7, 1, 6, 6, 4, 0, 3, 9, 8, 0, 2, 2, 6, 1, 3, 7, 9, 8, 3, 4, 3, 8, 9, 7, 6, 5, 6, 7, 9, 3, 2, 2, 9, 3, 7, 1, 0, 7, 2, 2, 0, 2, 6, 2, 7, 7, 8, 4, 0, 5, 4, 9, 0, 9, 6, 9, 4, 9, 1, 7, 8, 4, 1, 4, 9, 5, 7, 3, 6, 5, 0, 4, 6, 9, 4, 6, 9, 5, 7, 3, 5, 0, 9, 6, 2, 8, 5, 5, 1, 8, 4, 5, 5, 6, 1, 8, 5, 8, 4, 6, 5, 7, 4, 8, 0, 3, 6, 4, 4, 0, 9, 9, 4, 6, 1, 2, 3, 0, 0, 4, 7, 5, 5, 6, 1, 1, 5, 9, 2, 2, 4, 5, 1, 5, 2, 5, 6, 9, 5, 9, 3, 2, 4, 3, 3, 5, 4, 8, 4, 7, 5, 3, 5, 7, 9, 1, 1, 2, 8, 9, 2, 1, 4, 8, 5, 0, 9, 8, 1, 8, 9, 4, 3, 9, 1, 7, 1, 8, 2, 9, 4, 4, 5, 
8, 1, 0, 4, 1, 8, 6, 9, 7, 8, 7, 8, 4, 3, 2, 9, 3, 5, 8, 0, 5, 4, 0, 5, 8, 5, 5, 6, 3, 2, 0, 4, 0, 1, 4, 8, 4, 5, 2, 6, 8, 0, 8, 2, 7, 3, 4, 0, 4, 4, 8, 9, 9, 4, 2, 3, 8, 5, 0, 6, 0, 2, 6, 4, 1, 1, 9, 0, 5, 2, 2, 5, 6, 0, 2, 3, 8, 8, 9, 2, 3, 2, 3, 6, 9, 3, 9, 2, 3, 6, 5, 1, 9, 1, 4, 4, 5, 7, 8, 1, 8, 1, 6, 5, 7, 8, 4, 5, 6, 3, 6, 6, 9, 4, 3, 6, 7, 1, 8, 9, 7, 6, 2, 7, 4, 5, 7, 2, 6, 6, 7, 2, 7, 0, 0, 2, 1, 6, 9, 9, 2, 5, 5, 6, 3, 1, 6, 4, 3, 9, 8, 2, 1, 5, 3, 7, 0, 3, 9, 2, 2, 4, 5, 1, 8, 7, 7, 9, 8, 0, 7, 4, 9, 8, 4, 5, 9, 6, 6, 1, 8, 6, 4, 1, 4, 0, 6, 8, 0, 6, 0, 6, 2, 0, 4, 9, 2, 1, 0, 7, 3, 6, 4, 5, 8, 9, 1, 7, 3, 0, 3, 5, 9, 0, 0, 8, 5, 2, 5, 4, 5, 9, 9, 1, 3, 6, 4, 6, 1, 8, 2, 5, 0, 2, 9, 9, 6, 5, 0, 6, 2, 8, 8, 5, 6, 4, 7, 0, 3, 9, 8, 3, 6, 5, 3,  ...

# %%
np.argmax(new_labels)
# Out:
# 1

# %%
from syft.frameworks.torch.differential_privacy import pate
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0725 20:40:53.602245 4390966720 secure_random.py:26] Falling back to insecure randomness since the required custom op could not be found for the installed version of TensorFlow. Fix this by compiling custom ops. Missing file was '/Users/annascott/miniconda3/envs/pysyft/lib/python3.7/site-packages/tf_encrypted/operations/secure_random/secure_random_module_tf_1.14.0.so'
# W0725 20:40:53.667783 4390966720 deprecation_wrapper.py:119] From /Users/annascott/miniconda3/envs/pysyft/lib/python3.7/site-packages/tf_encrypted/session.py:26: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.

# %%
num_teachers, num_examples, num_labels = (100, 100, 10)
preds = (np.random.rand(num_teachers,num_examples)*num_labels).astype(int)
indices = (np.random.rand(num_examples)*num_labels).astype(int)

# %%
pate.perform_analysis(teacher_preds = preds, indices = indices, noise_eps=0.1, delta=1e-5)
# Out:
# (11.756462732485105, 11.756462732485115)

# %%
data_dep_eps, data_ind_eps = pate.perform_analysis(teacher_preds=preds, indices=indices, noise_eps=0.1, delta=1e-5)
print("Data Independent Epsilon:", data_ind_eps)
print("Data Dependent Epsilon:", data_dep_eps)
# Out:
# Data Independent Epsilon: 11.756462732485115
# Data Dependent Epsilon: 11.756462732485105

# %%
preds[:, 0:5] *= 0

# %%
data_dep_eps, data_ind_eps = pate.perform_analysis(teacher_preds=preds, indices=indices, noise_eps=0.1, delta=1e-5)
print("Data Independent Epsilon:", data_ind_eps)
print("Data Dependent Epsilon:", data_dep_eps)
# Out:
# Data Independent Epsilon: 11.756462732485115
# Data Dependent Epsilon: 7.3144247166586425

# %%
preds[:, 0:50] *= 0

# %%
data_dep_eps, data_ind_eps = pate.perform_analysis(teacher_preds=preds, indices=indices, noise_eps=0.1, delta=1e-5)
print("Data Independent Epsilon:", data_ind_eps)
print("Data Dependent Epsilon:", data_dep_eps)
# Out:
# Warning: May not have used enough values of l. Increase 'moments' variable and run again.
# Data Independent Epsilon: 11.756462732485115
# Data Dependent Epsilon: 1.52655213289881
